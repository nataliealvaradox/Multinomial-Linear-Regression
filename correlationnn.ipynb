# %%
 #Import library
import pandas  as pd #Data manipulation
import numpy as np #Data manipulation
import matplotlib.pyplot as plt # Visualization
import seaborn as sns #Visualization
# sns.set_style("darkgrid")
# plt.rcParams['figure.figsize'] = [10,5]
plt.rcParams['font.size'] =14
plt.rcParams['font.weight']= 'bold'
plt.style.use('seaborn-darkgrid')

# helpful https://www.kaggle.com/code/sudhirnl7/linear-regression-tutorial

# %%
# Import dataset
#path ='dataset/'
df = pd.read_csv('TOD_data.csv')
df = df.drop(['respond_id'], axis=1)
print('\nNumber of rows and columns in the data set: ',df.shape)
print('')

#Lets look into top few rows and columns in the dataset
df.head()
# Out:
# Number of rows and columns in the data set:  (10, 8)
#    TOD  food_stamps  unemployment   poverty  costburden_home  costburden_rent  \
# 0    1    -0.154325          -3.6  0.280952        -3.109509         7.852273
# 1    1     1.900000          -1.2 -1.400000         5.407224         2.321946
# 2    1     0.300000          -4.5 -1.100000        -6.259745         0.152856
# 3    1     1.216554          -5.0 -0.200000       -20.772795        -2.703572
# 4    1    -0.300000          -3.7 -2.600000        -7.546546        -7.071682
#
#    overcrowding  log_rent
# 0      0.709220  0.010408
# 1      4.748480  0.028461
# 2     -1.551557  0.053549
# 3     -0.373229  0.007005
# 4     -1.397501  0.055022

# %%
# correlation plot
corr = df.corr()
sns.color_palette("crest", as_cmap=True)
sns.heatmap(corr, cmap = "crest", annot= True)
# Out:
# <AxesSubplot:>
